# %% [markdown]
# # ¡Bienvenido al mundo de Python! 🐍
#
# ¿Alguna vez te has preguntado cómo sabe **TikTok** qué vídeo te va a gustar? ¿O cómo elige **Netflix** tu próxima serie favorita? Detrás de la magia de tus aplicaciones favoritas hay instrucciones escritas en lenguajes de programación. Y el rey indiscutible de esos lenguajes es **Python**.
#
# Python nació en 1991 gracias a un programador llamado *Guido van Rossum*. Como dato curioso: ¡no le puso ese nombre por la serpiente! Se lo dio porque era un gran fan de un grupo de comediantes de la televisión llamados *Monty Python*.
#
# ```{admonition} ¿Por qué te va a encantar Python? 🚀
# :class: tip
#
# * **Es como hablar en inglés:** Su sintaxis es tan limpia que parece que estás escribiendo frases normales.
# * **Es un superpoder:** Lo usan desde científicos de la NASA hasta creadores de videojuegos.
# * **Es el idioma de la Inteligencia Artificial:** Si quieres crear un bot o una IA en el futuro, este es el camino.
# ```

# %% [markdown]
# ## Ejemplo práctico: Tu primer código en Python 💻

# %% [markdown]
# En programación, existe una tradición sagrada: el primer programa que escribes en cualquier lenguaje siempre debe mostrar en pantalla el mensaje **"¡Hola, Mundo!"**.
#
# Para conseguir que el ordenador nos hable, usamos un comando o función mágica llamada `print()` (que en inglés significa *imprimir* o *mostrar en pantalla*). El texto que queremos que diga debe ir metido obligatoriamente entre **comillas** `""` y dentro de los **paréntesis** `()`. ¡Vamos a probarlo!

# %%
# Esto es un comentario. El ordenador lo ignora, ¡pero a nosotros nos ayuda a entender el código!
# Dale al botón de "Play" (ejecutar) para ver qué pasa aquí abajo:

print("¡Hola, Mundo! Acabo de programar mi primera línea en Python 🚀")

# %% [markdown]
# ---
#
# ## 🎯 Tus primeros Desafíos
#
# ¡Es hora de que tomes el control! Haz clic en la celda de código de abajo, modifica lo que necesites y pulsa ejecutar para superar estos retos:
#
# 1. **El Desafío del Nombre:** Cambia el texto para que el ordenador te salude a ti personalmente (ejemplo: *"¡Hola, Carlos!"*).
# 2. **El Desafío de los Emojis:** Intenta añadir tus emojis favoritos dentro de las comillas. ¿Es capaz Python de mostrarlos?
# 3. **El Desafío del Hacker (Error intencionado):** Borra una de las comillas de tu código e intenta ejecutarlo. Mira el mensaje rojo que sale. ¡No te asustes! Romper cosas y leer los errores es como aprenden los verdaderos programadores.

# %% [markdown]
# ### Desafío 1:

# %% [markdown]
# Cambia el texto para que el ordenador te salude a ti personalmente (ejemplo: *"¡Hola, Carlos!"*).

# %%
# Escribe aquí tu solución para los desafíos. 
# Modifica el texto que está entre las comillas:

print("¡Hola, aquí va tu nombre!")

# %% [markdown]
# ### Desafío 2:

# %% [markdown]
# Cambia el valor de la variable `edad` a tu edad actual y ejecuta el código para ver cómo cambia el mensaje.

# %%
# Esto es un comentario que no se procesará
print("Bienvenid@ a Educación Dixital en el IES Frei Martín Sarmiento")

# Calculadora sencilla usando variables
edad = 14
print("En 3º ESO tienes", edad, "años.")
edad_4eso = edad + 1
print("En 4º ESO tendrás", edad_4eso, "años.")

# %% [markdown]
# ### Desafío 3:

# %% [markdown]
#  Cambia el valor de las variables `edad` y `edad_4eso` para que reflejen tu edad actual y la edad que tendrás el próximo año. Ejecuta el código para ver los nuevos mensajes.

# %%
# Personaliza este programa con tus datos
nombre = "Tu nombre aquí"
instituto = "Tu instituto aquí"
ciudad = "Pontevedra"
edad = 12
dias_vividos = edad * 365   
horas_vividas = dias_vividos * 24  
print(f"Hola, soy {nombre} de {instituto} ({ciudad})")
print(f"Llevo aproximadamente {dias_vividos} días en este mundo o {horas_vividas} horas.")
print("Este año aprenderé programación en Python porque tengo un gran profesor ")
