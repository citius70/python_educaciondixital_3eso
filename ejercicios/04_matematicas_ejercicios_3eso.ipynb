# %% [markdown]
# # 🎯 Ejercicios: operaciones matemáticas en Python
#
# En este notebook practicarás diferentes **operaciones matemáticas** utilizando Python y la biblioteca `math`.
# Completa los ejercicios siguientes en las celdas de código.

# %% [markdown]
# :::{exercise}
# :label: matematicas-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la operación de **suma**, **resta**, **multiplicación** y **división** en Python.
#
# **Ejemplo de referencia**:
# ```python
# a = 9
# b = 7
#
# suma = a + b
# resta = a - b
# multiplicacion = a * b
# division = a / b
#
# print(suma)            # Resultado: 16
# print(resta)           # Resultado: 2
# print(multiplicacion)  # Resultado: 63
# print(division)        # Resultado: 1.2857142857142858
# ```
#
# **Instrucciones del ejercicio**:
#
# 1. Crea dos **variables** `x` e `y` con los valores `6` y `3` respectivamente.
# 2. Realiza la **suma** de ambas, guardando el resultado en una variable llamada `resultado1`.
# 3. Realiza la **resta** de ambas, guardando el resultado en una variable llamada `resultado2`.
# 4. Realiza la **multiplicación** de ambas, guardando el resultado en una variable llamada `resultado3`.
# 5. Realiza la **división** de ambas, guardando el resultado en una variable llamada `resultado4`.
# 6. Imprime los resultados usando `print()` con mensajes claros.
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# Solución del ejercicio 1

# Escribe aquí tu código

# %% [markdown]
# :::{exercise}
# :label: matematicas-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Practicar las operaciones de **división entera**, **módulo** (resto) y **potencia** en Python.
#
# **Ejemplo de referencia**:
# ```python
# a = 20
# b = 6
#
# division_int = a // b
# resto = a % b
# potencia = a ** b
#
# print(division_int)  # Resultado: 3
# print(resto)         # Resultado: 2
# print(potencia)      # Resultado: 64000000
# ```
#
# **Instrucciones del ejercicio**:
#
# 1. Crea dos variables `x` e `y` con los valores `15` y `7` respectivamente.
# 2. Realiza la **división entera** (`//`) de `x` entre `y`. Guarda el resultado en una variable llamada `div_int`.
# 3. Calcula también el **módulo** (`%`) de las mismas. Guarda el resultado en una variable llamada `resto`.
# 4. Realiza la **potencia** de `x` elevado a `y` y guarda el resultado en una variable llamada `potencia`.
# 5. Imprime los resultados usando `print()`. El mensaje puede ser parecido a:
#    `"La división entera es: ..."`, `"El resto es: ..."`, `"La potencia es: ..."`.
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# Solución del ejercicio 2

# Escribe aquí tu código

# %% [markdown]
# :::{exercise}
# :label: matematicas-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Practicar el uso de la biblioteca `math` para cálculos geométricos de triángulos rectángulos.
#
# > Recuerda el teorema de Pitágoras: en un triángulo rectángulo, el cuadrado de la hipotenusa es igual a la suma de los cuadrados de los catetos.
#
# $$\text{hipotenusa}^2 = \text{cateto}_a^2 + \text{cateto}_b^2$$
#
# $$\text{hipotenusa} = \sqrt{\text{cateto}_a^2 + \text{cateto}_b^2}$$
#
# **Ejemplo de referencia**:
# ```python
# import math
#
# # Calcular la hipotenusa de un triángulo rectángulo
# catetoA = 3
# catetoB = 4
# hipotenusa = math.sqrt(catetoA**2 + catetoB**2)
# print(f"Hipotenusa: {hipotenusa}")   # Resultado: 5.0
# ```
#
# **Instrucciones del ejercicio**:
#
# 1. Importa la biblioteca `math`.
# 2. Define dos variables `catA` y `catB` con los valores `8` y `5` respectivamente.
# 3. Calcula la **hipotenusa** usando la librería `math` y el teorema de Pitágoras: hipotenusa = `math.sqrt(catA**2 + catB**2)`.
# 4. Calcula también el **área del triángulo** usando la fórmula `(base × altura) / 2`, tomando `catA` como base y `catB` como altura.
# 5. Imprime tanto la **hipotenusa** como el **área** con mensajes descriptivos.
#
# ```{figure} ../_images/tri.PNG
# ---
# name: fig-triangulo
# width: 50%
# alt: Triángulo rectángulo
# ---
# Teorema de Pitágoras
# ```
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# Solución del ejercicio 3

# Escribe aquí tu código

# %% [markdown]
# :::{exercise}
# :label: matematicas-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Practicar el uso combinado de operaciones básicas y funciones sencillas (`abs`, `round`, `max`, `min`).
#
# **Instrucciones del ejercicio**:
#
# 1. Crea una lista llamada `numeros` con estos valores: `[3, -7, 10, -2, 5]`.
# 2. Calcula el **mayor** y el **menor** de la lista usando `max()` y `min()`.
# 3. Calcula el **valor absoluto** del número `-7` usando `abs()`.
# 4. Calcula la **media** de los números de la lista "a mano": suma todos los números y divide entre 5.
# 5. Muestra la media redondeada a 2 decimales usando `round(media, 2)`.
# 6. Imprime todos los resultados con `print()` y mensajes claros.
#
# **Escribe tu solución en la celda de código siguiente**:
#
# :::

# %%
# Solución del ejercicio 4

# Escribe aquí tu código

# %% [markdown]
# ```{admonition} Desafío opcional
# :class: tip
#
# Crea una **mini calculadora de áreas** que pregunte al usuario qué figura quiere calcular:
#
# - Si escribe `cuadrado`, pide el lado y calcula el área.
# - Si escribe `círculo`, pide el radio y calcula el área usando `math.pi`.
#
# Muestra el resultado con un mensaje claro. Si la opción no es válida, muestra un mensaje de error.
# ```
