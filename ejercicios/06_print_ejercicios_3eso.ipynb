# %% [markdown]
# # 🎯 Ejercicios: función `print()`
#
# En este notebook, practicarás el uso de la función `print()` en Python. Completa los ejercicios escribiendo el código en las celdas que el profesor te indique.

# %% [markdown]
# ::: {exercise}
# :label: print-ejercicio-1
# :class: ejercicio-practico
#
# **Objetivo**: Practicar la función `print()` con un mensaje simple.
#
# **Ejemplo de referencia**:
# ```python
# print("¡Hola, mundo!")
# # Resultado: ¡Hola, mundo!
# ```
#
# **Instrucciones del ejercicio**:
# 1. Usa la función `print()` para mostrar el mensaje **"¡Adiós, amigo!"** en la consola.
#
# :::

# %% [markdown]
# ::: {exercise}
# :label: print-ejercicio-2
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir varios datos usando `print()`.
#
# **Ejemplo de referencia**:
# ```python
# nombre = "Juan"
# edad = 25
# print("Mi nombre es", nombre, "y tengo", edad, "años")
# # Resultado: Mi nombre es Juan y tengo 25 años
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea dos variables: `name` con tu nombre y `age` con tu edad.
# 2. Usa `print()` para mostrar una frase como: "Mi nombre es [nombre] y tengo [edad] años".
#
# :::

# %% [markdown]
# ::: {exercise}
# :label: print-ejercicio-3
# :class: ejercicio-practico
#
# **Objetivo**: Usar f-strings para escribir frases con variables.
#
# **Ejemplo de referencia**:
# ```python
# asignatura = "Matemáticas"
# nota = 8.5
# print(f"En {asignatura} he sacado un {nota}.")
# # Resultado: En Matemáticas he sacado un 8.5.
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea dos variables: `radio = 7` y `pi = 3.1416`.
# 2. Calcula el área de un círculo con la fórmula `area = pi * radio ** 2`.
# 3. Usa un f-string para mostrar un mensaje como: "El área del círculo de radio 7 es [area] cm2".
# 4. Muestra el área con 2 decimales usando el formato `{area:.2f}` dentro del f-string.
#
# :::

# %% [markdown]
# ::: {exercise}
# :label: print-ejercicio-4
# :class: ejercicio-practico
#
# **Objetivo**: Imprimir listas con `print()`.
#
# **Ejemplo de referencia**:
# ```python
# frutas = ["manzana", "banana", "naranja"]
# print(frutas)
# ```
#
# **Instrucciones del ejercicio**:
# 1. Crea una lista llamada `colores` con **cinco colores que te gusten**.
# 2. Usa `print()` para mostrar la lista completa.
# 3. (Opcional) Usa `print()` para mostrar solo el primer color de la lista.
#
# :::
