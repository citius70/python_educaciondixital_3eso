# %% [markdown]
# # 🎯 Ejercicios con listas
#
# Practica operaciones básicas con listas en Python.

# %% [markdown]
# :::{exercise}
# :label: listas-ejercicio-1
# :class: ejercicio-practico
#
# ## Ejercicio 1: Índices
#
# Dada la siguiente lista de países, imprime:
#
# 1. `México` usando su índice.
# 2. `Luxemburgo` usando su índice.
# 3. `Australia` usando un índice negativo.
# 4. Añade `Francia` al final de la lista con `append()`.
# 5. Muestra la lista final.
#
# **Pista**: recuerda que el primer elemento tiene índice `0`.
# :::

# %%
paises = ["Luxemburgo", "Brasil", "Canadá", "Francia", "Japón", "México", "Alemania", "Italia", "España", "Australia"]

# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: listas-ejercicio-2
# :class: ejercicio-practico
#
# ## Ejercicio 2: Añadir y quitar frutas
#
# 1. Crea una lista de tres frutas.
# * Muestra la lista inicial.
# 2. Añade una fruta usando `append()`.
# * Muestra la lista actual.
# 3. Elimina la fruta que tiene de **índice 2**.
# * Muestra la lista actual.
# 4. Recorre la lista con la función `for()` y muestra en pantalla: "Me gustan mucho las, *(sustituye por cada fruta)*"
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: listas-ejercicio-3
# :class: ejercicio-practico
#
# ## Ejercicio 3: Ordenar números
#
# Crea una lista con 5 números desordenados y:
#
# 1. Ordénala de menor a mayor con `sort()`.
# 2. Muestra la lista ordenada.
# 3. Invierte el orden con `reverse()`.
# 4. Muestra la lista invertida.
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: listas-ejercicio-4
# :class: ejercicio-practico
#
# ## Ejercicio 4: Contar y buscar colores
#
# Dada la lista de colores:
#
# 1. Muestra cuántos elementos tiene con `len()`.
# 2. Pide un color al usuario y cuenta cuántas veces aparece con `count()`.
#
# **Pista**: usa `in` antes de aplicar `count()`
# :::

# %%
colores = ['morado', 'marrón', 'violeta', 'azul', 'verde', 'rosa', 'gris', 'rojo', 'azul', 'turquesa', 'verde', 'rojo', 'beige', 'rojo', 'naranja', 'blanco', 'amarillo', 'negro', 'rojo', 'azul', 'celeste']

# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: listas-ejercicio-5
# :class: ejercicio-practico
#
# ## Ejercicio 5: Slices básicosº
#
# Dada esta lista de ciudades:
#
# 1. Imprime los 5 primeros elementos.
# 2. Imprime el slice desde "Los Ángeles" hasta "Phoenix".
#
# **Pista**: puedes usar `lista[?:?] cambiando los ? por índices.`
# :::

# %%
ciudades = ["Nueva York", "Los Ángeles", "Chicago", "Houston", "Phoenix", "Filadelfia", "San Antonio", "San Diego", "Dallas", "San José"]

# Escribe tu código aquí

# %% [markdown]
# ## ✅ Lo que has practicado
#
# - Usar índices para acceder a elementos de una lista.
# - Añadir y quitar elementos con `append()` y `remove()`.
# - Ordenar y revertir listas con `sort()` y `reverse()`.
# - Contar elementos con `len()` y buscar con `count()` e `index()`.
# - Obtener partes de una lista con slices sencillos.
