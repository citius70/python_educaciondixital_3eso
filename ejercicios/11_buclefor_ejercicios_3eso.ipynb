# %% [markdown]
# # 🎯 Ejercicios: bucle `for`
#
# ## Practica los bucles con ejemplos sencillos

# %% [markdown]
# En este cuaderno practicarás el uso de `for` para repetir acciones, recorrer listas y trabajar con rangos.
#
# **Recuerda:**
# - `range(inicio, fin)` genera números desde inicio hasta fin-1.
# - El bloque dentro del bucle lleva sangría.
# - Puedes recorrer listas, cadenas y secuencias con `for`.
# - `enumerate()` ayuda a contar posiciones cuando hace falta.

# %% [markdown]
# ## Ejercicio resuelto
#
# **Imprimir números del 1 al 10**
#
# Programa que imprime los números del 1 al 10 usando un bucle `for`.

# %%
for numero in range(1, 11):
    print(numero)

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-1
# :class: ejercicio-practico
#
# ## Imprimir números del 5 al 20 (en saltos de 2)
#
# Escribe un programa que imprima los números del 5 al 20, pero en saltos de 2, utilizando un bucle `for`.
#
# **Pista:** usa `range(5, 21, 2)`.
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-2
# :class: ejercicio-practico
#
# ## Imprimir una lista de asignaturas
#
# Escribe un programa que tenga una lista de seis asignaturas y use un bucle `for` para imprimir cada elemento.
#
# **Pista:** recorre una lista con `for asignatura in lista:`.
# **Pista:** utiliza `print("Hoy estudio", asignatura)` para mostrar el mensaje.
# :::

# %%
# Escribe tu código aquí
# Out:
# No se pudo iniciar el Kernel.
#
# No se ha podido iniciar el Kernel "venv (Python 3.13.12)" debido a un tiempo de espera para que se utilicen los puertos.
#
# Ver Jupyter <a href='command:jupyter.viewOutput'>log</a> para más detalles.

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-3
# :class: ejercicio-practico
#
# ## Tabla de multiplicar
#
# Escribe un programa que pida al usuario un número y luego imprima la tabla de multiplicar de ese número del 1 al 10.
#
# **Pista:** combina `input()` con `range(1, 11)`.
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: for-ejercicio-4
# :class: ejercicio-practico
#
# ## Contar vocales
#
# Escribe un programa que pida al usuario una frase y cuente cuántas vocales hay en ella utilizando un bucle `for`.
#
# **Pista:** recorre la frase letra a letra y comprueba si es vocal.
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# ---
#
# ## 🚀 Desafío final
#
# Crea un programa que **pida un número al usuario** y muestre todos sus **divisores**.
# **Recuerda** que un divisor de un número es cualquier número que lo divide exactamente sin dejar residuo (resto).
#
# Intenta usar `for`, `if` y el operador `%` de forma ordenada.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ---
#
# ## ✅ Lo que has practicado
#
# - Uso de `for` con `range()`
# - Recorrido de listas y cadenas
# - Acumulación de resultados en variables
# - Resolución de problemas sencillos con bucles
