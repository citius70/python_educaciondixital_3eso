# %% [markdown]
# # 🎯 Ejercicios con Diccionarios

# %% [markdown]
# :::{exercise}
# :label: dic-ejercicio-1
# :class: ejercicio-practico
#
# ## Ejercicio 1: Consultar precios
#
# Dado el siguiente diccionario de productos, crea un programa que permita al usuario **consultar el precio** de un producto.
#
# ```python
# productos = {
#     "manzana": 1.5,
#     "banana": 0.5,
#     "naranja": 0.75,
#     "uva": 2.0,
#     "pera": 1.0
# }
# ```
#
# **Pasos**
# 1. Copia el diccionario `productos`.
# 2. Imprime el diccionario completo.
# 3. Pide al usuario el nombre de un producto, indicando que puede escribir "salir" para terminar.
# 4. Mientras la respuesta no sea "salir":
#    - Si el producto está en el diccionario, muestra su precio.
#    - Si no está, indica que ese producto no existe.
#    - Vuelve a preguntar el nombre de un producto.
# 5. Cuando el usuario escriba "salir", muestra un mensaje de despedida.
#
# **Pista**: usa el operador `in` para comprobar si una clave está en el diccionario (`if producto in productos:`).
# :::

# %% [markdown]
# :::{exercise}
# :label: dic-ejercicio-1
# :class: ejercicio-practico
#
# ## Ejercicio 1: Almacenar y mostrar un diccionario sencillo
#
# Crea un programa que guarde el **nombre y la edad** de varias personas, y que termine cuando el usuario escriba "salir".
#
# **Pasos**
# 1. Crea un diccionario vacío llamado `persona`.
# 2. Pide al usuario su **nombre**. Si escribe "salir", termina el programa.
# 3. Si no escribe "salir", pide también su **edad**.
# 4. Guarda el nombre como **clave** y la edad como **valor** en el diccionario `persona`.
# 5. Vuelve a preguntar (repite los pasos 2-4) hasta que el usuario escriba "salir".
# 6. Cuando termine, imprime el diccionario `persona` completo.
#
# **Pista**: necesitarás un bucle `while True:` con un `break` para salir cuando el nombre sea "salir".
# :::

# %%
# 1. Crear un diccionario vacío llamado persona


# 2-5. Repetir mientras el usuario no escriba "salir":
#   - Pedir el nombre
#   - Si es "salir", salir del bucle
#   - Si no, pedir la edad y guardar nombre:edad en el diccionario


# 6. Imprimir el contenido del diccionario persona

# %% [markdown]
# :::{exercise}
# :label: dic-ejercicio-3
# :class: ejercicio-practico
#
# ## Ejercicio 3: Actualizar precios
#
# Usando el mismo diccionario de productos, crea un programa que permita **cambiar el precio** de un producto que ya existe, o **añadir un producto nuevo** si no existe todavía.
#
# ```python
# productos = {
#     "manzana": 1.5,
#     "banana": 0.5,
#     "naranja": 0.75,
#     "uva": 2.0,
#     "pera": 1.0
# }
# ```
#
# **Pasos**
# 1. Copia el diccionario `productos`.
# 2. Pide al usuario el nombre de un producto.
# 3. Pide al usuario el nuevo precio para ese producto.
# 4. Usa `update()` para guardar ese precio:
#    - Si el producto ya existía, se actualiza su precio.
#    - Si no existía, se añade como producto nuevo.
# 5. Imprime el diccionario `productos` actualizado.
#
# **Pista**: no necesitas comprobar si el producto existe o no antes de usar `update()`: el método ya hace las dos cosas (actualizar o añadir) automáticamente.
# :::

# %%
# 1. Copia y pega el diccionario de productos


# 2. Pedir al usuario que ingrese el nombre de un producto


# 3. Pedir al usuario que ingrese el nuevo precio


# 4. Actualizar (o añadir) el producto en el diccionario con update()


# 5. Imprimir el diccionario actualizado
