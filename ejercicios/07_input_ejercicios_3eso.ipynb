# %% [markdown]
# # 🎯 Ejercicios: función `input()`
#
# En este notebook, practicarás el uso de la función `input()` en Python. Completa los ejercicios a continuación escribiendo tu código donde se indica.

# %% [markdown]
# ## Ejercicio resuelto
#
# Programa que pide al usuario la ciudad en la que nació y luego imprime una frase con la respuesta.
#
# ```python
# # Solicitar el nombre y la ciudad en la que nació el usuario
# nombre = input("¿Cuál es tu nombre?: ")
# ciudad = input("¿Dónde naciste?: ")
#
# # Imprimir una frase personalizada
# print(f"{nombre} nació en {ciudad}.")
# ```

# %% [markdown]
# ::: {exercise}
# :label: input-ejercicio-1
# :class: ejercicio-practico
#
# ## Ejercicio 1: Saludo personalizado
#
# Escribe un programa que pida al usuario su nombre y luego imprima un saludo personalizado.
#
# **Instrucciones:**
# - Solicita el nombre del usuario con la función `input` y guárdalo en la variable `name`.
# - Imprime un saludo personalizado con la función `print`.
# - Hazlo primero sin f-strings y luego usando un f-string.
#
# ```python
# # Escribe el código aquí
# ```
# :::

# %% [markdown]
# ::: {exercise}
# :label: input-ejercicio-2
# :class: ejercicio-practico
#
# ## Ejercicio 2: Calcular el doble de un número
#
# Escribe un programa que pida al usuario un número y luego imprima el doble de ese número.
#
# **¡Atención!** La función `input()` devuelve como respuesta *cadenas de texto*.
# Si quieres tratarlo como número debes convertir la respuesta a entero o decimal (`int` o `float`).
#
# **Instrucciones:**
# - Solicita al usuario un número.
# - Convierte ese texto a número (`int` o `float`) y guárdalo en la variable `numero`.
# - Calcula el doble del número y guárdalo en la variable `doble`.
# - Imprime el resultado. Puedes usar esta línea, descomentándola:
#
# ```python
# # print(f"El doble de {numero} es {doble}.")
# ```
#
# ```python
# # Escribe el código aquí
# ```
# :::

# %% [markdown]
# ::: {exercise}
# :label: input-ejercicio-3
# :class: ejercicio-practico
#
# ## Ejercicio 3: Cálculo de la suma
#
# Escribe un programa que pida al usuario dos números y luego imprima la suma de esos números.
#
# **Instrucciones:**
# - Solicita dos números al usuario.
# - Te dejo la primera línea de ayuda:
#
# ```python
# number1 = float(input("Ingresa el primer número: "))
# ```
#
# - Pide también el segundo número y conviértelo a `float`.
# - Calcula la suma y guárdala en la variable `suma`.
# - Imprime el resultado con un f-string usando `print()`.
#
# ```python
# # Escribe el código aquí
# ```
# :::

# %% [markdown]
# ::: {exercise}
# :label: input-ejercicio-4
# :class: ejercicio-practico
#
# ## Ejercicio 4: Cálculo de la edad
#
# Escribe un programa que pida al usuario su edad y luego imprima su edad el año que viene.
#
# **Instrucciones:**
# - Solicita al usuario su edad y conviértela a entero.
# - Calcula la edad del próximo año.
# - Imprime el resultado.
#
# ```python
# # Escribe el código aquí
# ```
# :::
