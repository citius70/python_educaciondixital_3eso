# %% [markdown]
# # 🎯 Ejercicios: bucle `while`
#
# En este cuaderno practicarás el uso del bucle `while` para repetir acciones mientras se cumpla una condición.

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-1
# :class: ejercicio-practico
#
# ## Ejercicio 1: Repetir un mensaje 🔁
#
# **Objetivo**: Usar un bucle `while` con un contador para repetir el mensaje `Estoy aprendiendo Python` varias veces.
#
# **Instrucciones**:
#
# 1. Crea una variable `contador` que empiece en 1.
# 2. Mientras `contador` sea menor o igual que 5, muestra el mensaje `Estoy aprendiendo Python` por pantalla.
# 3. En cada vuelta del bucle, aumenta `contador` en 1.
#
# **Pista**:
#
# ```python
# contador = 1
#
# while contador <= 5:
#     # aquí va el print
#     # aquí sumas 1 al contador
# ```
#
# **Escribe tu solución en la celda de código siguiente:**
# :::

# %%
# Escribe tu código aquí

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-2
# :class: ejercicio-practico
#
# ## Ejercicio 2: Cuenta atrás sencilla ⏱️
#
# **Objetivo**: Usar un bucle `while` para ir **restando** un contador hasta llegar a 0.
#
# **Enunciado**:
#
# 1. Pide al usuario un número entero positivo.
# 2. Usa un bucle `while` que se ejecute **mientras** el número sea mayor que 0.
# 3. En cada vuelta:
#    - Muestra el número actual.
#    - Resta 1 al número.
# 4. Cuando el número llegue a 0, muestra el mensaje: `¡Fin de la cuenta atrás!`.
#
# **Pista**:
#
# ```python
# numero = int(input("Escribe un número para empezar la cuenta atrás: "))
#
# while numero > 0:
#     # muestra el número
#     # resta 1 a 'numero'
#
# # aquí va el mensaje final
# ```
#
# **Escribe tu código en la celda siguiente.**
# :::

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-3
# :class: ejercicio-practico
#
# ## Ejercicio 3: Tabla de multiplicar
#
# **Objetivo**: Escribir un programa que muestre la tabla de multiplicar (del 1 al 10) de un número (`num`) introducido por el usuario.
#
# **Instrucciones**:
#
# 1. Pide al usuario un número entero.
# 2. Utiliza un bucle `while` para mostrar la tabla de multiplicar de ese número desde 1 hasta 10.
#
# **Ejemplo de salida** (si el usuario introduce 5):
#
# ```python
# 5 x 1 = 5
# 5 x 2 = 10
# ...
# 5 x 10 = 50
# ```
#
# **Pista**: Usa un contador que empiece en 1 y vaya subiendo hasta 10.
#
# **Ayuda**: Copia los comentarios del código de abajo y complétalo.
# :::

# %%
# Pide un número al usuario


# Inicializa el contador en 1


# Mientras el contador sea menor o igual a 10

    # Calcula el resultado de la multiplicación

    # Imprime la línea correspondiente de la tabla de multiplicar

    # Incrementa el contador en 1

# %% [markdown]
# :::{exercise}
# :label: while-ejercicio-4
# :class: ejercicio-practico
#
# ## Ejercicio 4: Hucha de ahorro
#
# **Objetivo**: Escribir un programa que simule una hucha para ahorrar, utilizando el bucle `while`.
#
# **Instrucciones**:
#
# 1. Pide primero una cantidad que se desea ahorrar (objetivo).
# 2. Luego, ve pidiendo cantidades a añadir a la hucha y súmalas a lo ahorrado.
# 3. El bucle `while` debe repetirse **mientras** la cantidad ahorrada sea menor que el objetivo.
# 4. Cada vez que el usuario introduzca una nueva cantidad, muestra:
#    - Cuánto lleva ahorrado.
#    - Cuánto le falta para llegar al objetivo.
#
# **Ejemplo de salida**:
#
# ```python
# Introduce la cantidad que deseas ahorrar: 100
# ---
# Introduce una cantidad para añadir a la hucha: 20
# Cantidad ahorrada: 20 euros. Te faltan 80 euros para alcanzar tu objetivo
# Introduce una cantidad para añadir a la hucha: 30
# Cantidad ahorrada: 50 euros. Te faltan 50 euros para alcanzar tu objetivo
# Introduce una cantidad para añadir a la hucha: 50
# ¡Felicidades! Has alcanzado tu objetivo de ahorro.
# ```
#
# **Pista**: Necesitas una variable para el objetivo y otra para el dinero ahorrado.
#
# **Ayuda**: Copia los comentarios del código de abajo y complétalo.
# :::

# %%
# Solicita al usuario la cantidad de dinero que desea ahorrar y guárdala en la variable 'objetivo'
# Usa float(input(...)) para poder trabajar con decimales


# Inicializa la variable 'ahorrado' en 0.0. Esta variable guardará el total ahorrado


# Inicia un bucle while que se ejecute mientras 'ahorrado' sea menor que 'objetivo'

    # Pide al usuario una cantidad para añadir a la hucha y guárdala en la variable 'cantidad'

    # Suma esa cantidad a la variable 'ahorrado'

    # Muestra por pantalla cuánto lleva ahorrado y cuánto le falta para llegar al objetivo

# Cuando termine el bucle, muestra un mensaje indicando que ha alcanzado el objetivo

# %% [markdown]
# ## ✅ ¿Qué has practicado?
#
# - Uso de bucles `while` con contadores.
# - Uso de bucles `while` con acumuladores.
# - Repetir acciones mientras se cumpla una condición.
# - Problemas del mundo real: tablas, ahorro y control de stock.
