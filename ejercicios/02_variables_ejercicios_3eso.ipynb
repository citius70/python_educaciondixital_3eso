# %% [markdown]
# # 🎯 Ejercicios: Variables

# %% [markdown]
# En este cuaderno vas a practicar todo lo que has aprendido sobre **variables** en Python. ¡Completa los ejercicios y conviértete en un experto! 💪

# %% [markdown]
# :::{tip} 💡 Consejo importante
# Después de escribir cada ejercicio, **ejecuta la celda** (presiona Shift + Enter) para ver si tu código funciona correctamente.
# :::

# %% [markdown]
# ---
#
# ## Ejercicio 1: Mi primera variable numérica
#
# :::{exercise}
# :label: variables-ejercicio-1
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Crear una variable con un número.
#
# **📖 Ejemplo de referencia:**
# ```python
# edad = 25
# print(edad)  # Muestra: 25
# ```
#
# **✍️ Tu turno:**
# 1. Crea una variable llamada `mi_edad`
# 2. Guarda tu edad actual en ella
# 3. Usa `print()` para mostrar el valor
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# ## Ejercicio 2: Variables de texto
#
# :::{exercise}
# :label: variables-ejercicio-2
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Crear una variable con texto.
#
# **📖 Ejemplo de referencia:**
# ```python
# nombre = "Juan"
# print(nombre)  # Muestra: Juan
# ```
#
# **✍️ Tu turno:**
# 1. Crea una variable llamada `mi_nombre`
# 2. Guarda tu nombre en ella (¡recuerda usar comillas!)
# 3. Usa `print()` para mostrar el valor
#
# 💡 **Pista**: El texto siempre va entre comillas: "así"
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# ## Ejercicio 3: Listas de valores
#
# :::{exercise}
# :label: variables-ejercicio-3
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Crear listas con varios valores.
#
# **📖 Ejemplo de referencia:**
# ```python
# frutas = ["manzana", "banana", "naranja"]
# print(frutas)
# ```
#
# **✍️ Tu turno:**
# 1. Crea una variable `series_favoritas` con una lista de 3 series de Netflix que te gusten
# 2. Crea otra variable `notas` con 4 calificaciones de ejemplo (pueden ser números del 1 al 10)
# 3. Muestra ambas listas con `print()`
#
# 💡 **Pista**: Las listas se escriben con corchetes: ["valor1", "valor2", "valor3"]
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# ## Ejercicio 4: Incrementar valores
#
# :::{exercise}
# :label: variables-ejercicio-4
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Aprender a aumentar el valor de una variable.
#
# **📖 Ejemplo de referencia:**
# ```python
# puntos = 0
# puntos = puntos + 10  # Sumamos 10 puntos
# print(puntos)  # Muestra: 10
# ```
#
# **✍️ Tu turno:**
# 1. Crea una variable `puntos_juego` con el valor 50
# 2. Suma 25 puntos más (usando `puntos_juego = puntos_juego + 25`)
# 3. Muestra el resultado con `print()`
#
# 💡 **Curiosidad**: También puedes escribir `puntos_juego += 25` (es lo mismo pero más corto)
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# ## Ejercicio 5: Unir textos
#
# :::{exercise}
# :label: variables-ejercicio-5
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Combinar varias variables de texto en una.
#
# **📖 Ejemplo de referencia:**
# ```python
# saludo = "Hola"
# nombre = "Juan"
# mensaje = saludo + ", " + nombre + "!"
# print(mensaje)  # Muestra: Hola, Juan!
# ```
#
# **✍️ Tu turno:**
# 1. Crea una variable `deporte` con tu deporte favorito
# 2. Crea una variable `equipo` con tu equipo favorito
# 3. Crea una variable `mensaje` que combine ambas: "Mi deporte favorito es [deporte] y mi equipo es [equipo]"
# 4. Muestra el mensaje con `print()`
#
# 💡 **Pista**: Usa el símbolo `+` para unir textos
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# %% [markdown]
# ---
#
# ## Ejercicio 6: 🌟 Mini-proyecto integrado
#
# :::{exercise}
# :label: variables-ejercicio-6
# :class: ejercicio-practico
#
# **🎯 Objetivo**: Crear un programa completo que use todo lo aprendido.
#
# **📖 Situación:** Imagina que tienes una tienda de videojuegos y necesitas llevar un inventario.
#
# **✍️ Pasos a seguir:**
#
# 1. Crea una variable `videojuego` con el nombre de un videojuego (por ejemplo: "Minecraft")
#
# 2. Crea una variable `cantidad` con el valor inicial de 10 unidades
#
# 3. Crea una variable `precio` con el valor 29.99 euros
#
# 4. Imagina que llegan 5 unidades más al almacén. Actualiza la variable `cantidad` sumándole 5
#
# 5. Calcula el valor total del inventario multiplicando `cantidad * precio` y guárdalo en una variable llamada `valor_total`
#
# 6. Crea un mensaje que diga: "Tengo [cantidad] copias de [videojuego] por un valor de [valor_total] euros"
#
# 7. Muestra el mensaje final con `print()`
#
# 💡 **Ayuda adicional**: Para convertir el número `valor_total` en texto y poder unirlo, usa `str(valor_total)`
#
# **Ejemplo de salida esperada:**
# ```
# Tengo 15 copias de Minecraft por un valor de 449.85 euros
# ```
#
# :::

# %%
# ESCRIBE TU CÓDIGO AQUÍ

# Paso 1: Nombre del videojuego


# Paso 2: Cantidad inicial


# Paso 3: Precio


# Paso 4: Llegan 5 unidades más


# Paso 5: Calcular valor total


# Paso 6 y 7: Crear y mostrar el mensaje

# %% [markdown]
# ---

# %% [markdown]
# ## 🏆 Desafío extra (opcional)
#
# Si has terminado todos los ejercicios, intenta crear tu propio programa. Algunas ideas:
#
# - 🎵 Un inventario de tus canciones favoritas con artista y año
# - 📚 Una lista de libros que quieres leer con su número de páginas
# - ⚽ Estadísticas de tu equipo favorito (partidos jugados, ganados, goles...)
# - 🎮 Información sobre tus personajes favoritos de videojuegos
#
# ¡Usa tu creatividad! 🚀

# %%
# TU DESAFÍO PERSONAL AQUÍ

# %% [markdown]
# ---
#
# ## ✅ Conclusión
#
# ¡Enhorabuena! 🎉 Has practicado la creación de **variables** en Python. Ahora sabes:
#
# - ✅ Crear variables con números y texto
# - ✅ Crear listas con varios valores
# - ✅ Modificar el valor de una variable
# - ✅ Combinar variables de texto
# - ✅ Usar variables en cálculos
#
# Sigue practicando y experimentando con diferentes tipos de datos. ¡Cada vez serás mejor! 💪
